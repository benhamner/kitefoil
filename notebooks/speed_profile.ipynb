# %%
import cProfile
import kitefoil

# %%
cProfile.run('kitefoil.KiteFoilSession("../gpx/activity_7422746557.gpx")')
# Out:
#          42269991 function calls (41851024 primitive calls) in 24.391 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#      7975    0.007    0.000    0.096    0.000 <__array_function__ internals>:2(any)
#        26    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(append)
#      8688    0.006    0.000    0.048    0.000 <__array_function__ internals>:2(argsort)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#     25357    0.018    0.000    0.119    0.000 <__array_function__ internals>:2(atleast_2d)
#        13    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
# ...
