# %%
import kitefoil

# %%
session = kitefoil.KiteFoilSession("../gpx/activity_7422746557.gpx")

# %%
session.windrose()

# %%
session.stats
# Out:
# {'start_time': Timestamp('2021-09-03 16:20:07-0700', tz='US/Pacific'),
#  'stop_time': Timestamp('2021-09-03 18:46:24-0700', tz='US/Pacific'),
#  'duration': Timedelta('0 days 02:26:17'),
#  'num_crashes': 15,
#  'num_starboard_tack_crashes': 6,
#  'num_port_tack_crashes': 10,
#  'time_elapsed_minutes': 146.28333333333333,
#  'minutes_per_crash': 9.752222222222223,
#  'transition_success_percent': 88.80597014925372,
#  'starboard_transition_success_percent': 90.76923076923077,
#  'port_transition_success_percent': 85.71428571428571,
#  'num_starboard_to_port_transitions': 59,
#  'num_port_to_starboard_transitions': 60}

# %%
session_crissyrace = kitefoil.KiteFoilSession("../gpx/activity_7417475679.gpx")

# %%
session_crissyrace.windrose()

# %%
session_crissyrace.stats
# Out:
# {'start_time': Timestamp('2021-09-02 17:21:43-0700', tz='US/Pacific'),
#  'stop_time': Timestamp('2021-09-02 18:43:03-0700', tz='US/Pacific'),
#  'duration': Timedelta('0 days 01:21:20'),
#  'num_crashes': 12,
#  'num_starboard_tack_crashes': 10,
#  'num_port_tack_crashes': 3,
#  'time_elapsed_minutes': 81.33333333333333,
#  'minutes_per_crash': 6.777777777777778,
#  'transition_success_percent': 75.0,
#  'starboard_transition_success_percent': 60.0,
#  'port_transition_success_percent': 87.5,
#  'num_starboard_to_port_transitions': 15,
#  'num_port_to_starboard_transitions': 21}
